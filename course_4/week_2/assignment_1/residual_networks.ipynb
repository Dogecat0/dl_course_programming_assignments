# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: tensorflow in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (2.8.0)
# Requirement already satisfied: numpy in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.22.2)
# Requirement already satisfied: scipy in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (1.8.0)
# Requirement already satisfied: matplotlib in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (3.5.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 1)) (1.1.2)
# Requirement already satisfied: six>=1.12.0 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: flatbuffers>=1.12 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 1)) (2.0)
# Requirement already satisfied: libclang>=9.0.1 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 1)) (13.0.0)
# Requirement already satisfied: setuptools in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 1)) (60.9.3)
# Requirement already satisfied: absl-py>=0.4.0 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 1)) (2.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 1)) (1.6.3)
# Requirement already satisfied: gast>=0.2.1 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 1)) (0.5.3)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 1)) (2.8.0.dev2021122109)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: protobuf>=3.9.2 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 1)) (3.19.4)
# Requirement already satisfied: h5py>=2.9.0 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 1)) (4.1.1)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 1)) (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 1)) (0.24.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 1)) (1.44.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 1)) (3.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 4)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 4)) (4.31.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 4)) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 4)) (3.0.7)
# Requirement already satisfied: packaging>=20.0 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 4)) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 4)) (1.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow->-r requirements.txt (line 1)) (0.37.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow->-r requirements.txt (line 1)) (2.27.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow->-r requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow->-r requirements.txt (line 1)) (3.3.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow->-r requirements.txt (line 1)) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow->-r requirements.txt (line 1)) (2.6.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow->-r requirements.txt (line 1)) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->-r requirements.txt (line 1)) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->-r requirements.txt (line 1)) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->-r requirements.txt (line 1)) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->-r requirements.txt (line 1)) (4.11.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->-r requirements.txt (line 1)) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->-r requirements.txt (line 1)) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->-r requirements.txt (line 1)) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->-r requirements.txt (line 1)) (3.3)
# Requirement already satisfied: zipp>=0.5 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->-r requirements.txt (line 1)) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->-r requirements.txt (line 1)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/wangzhicheng/opt/anaconda3/envs/dlcourse/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->-r requirements.txt (line 1)) (3.2.0)

# %%
import tensorflow as tf
import numpy as np
import scipy.misc
from tensorflow.keras.applications.resnet_v2 import ResNet50V2
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet_v2 import preprocess_input, decode_predictions
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from tensorflow.keras.models import Model, load_model
from resnets_utils import *
from tensorflow.keras.initializers import random_uniform, glorot_uniform, constant, identity
from tensorflow.python.framework.ops import EagerTensor
from matplotlib.pyplot import imshow

from test_utils import summary, comparator
import public_tests

# %matplotlib inline

# %%
# The identity block

def identity_block(X, f, filters, training=True, initializer=random_uniform):
    F1, F2, F3 = filters

    X_shortcut = X

    X = Conv2D(filters=F1, kernel_size=1, strides=(1,1), padding='valid', kernel_initializer=initializer(seed=0))(X)
    X = BatchNormalization(axis=3)(X, training=training)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=f, strides=(1,1), padding='same', kernel_initializer=initializer(seed=0))(X)
    X = BatchNormalization(axis=3)(X, training=training)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=1, strides=(1,1), padding='valid', kernel_initializer=initializer(seed=0))(X)
    X = BatchNormalization(axis=3)(X, training=training)

    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    return X

# %%
def convolutional_block(X, f, filters, s = 2, training=True, initializer=glorot_uniform):
    F1, F2, F3 = filters
    
    X_shortcut = X

    X = Conv2D(filters = F1, kernel_size = 1, strides = (s, s), padding='valid', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training=training)
    X = Activation('relu')(X)

    X = Conv2D(F2, (f, f), strides = (1,1), padding='same', kernel_initializer = initializer(seed=0))(X) 
    X = BatchNormalization(axis = 3)(X, training=training)
    X = Activation('relu')(X) 

    X = Conv2D(F3, (1, 1), strides = (1,1), padding='valid', kernel_initializer = initializer(seed=0))(X) 
    X = BatchNormalization(axis = 3)(X, training=training)
    
    X_shortcut = Conv2D(F3, (1, 1), strides = (s,s), padding='valid', kernel_initializer = initializer(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3)(X_shortcut, training=training)
    
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    return X

# %%
# ResNet model

def ResNet50(input_shape=(64,64,3), classes=6):
    X_input = Input(input_shape)

    X = ZeroPadding2D((3,3))(X_input)

    X = Conv2D(64, (7,7), strides=(2,2), kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3)(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3,3), strides=(2,2))(X)

    X = convolutional_block(X, f=3, filters=[64,64,256], s=1)
    X = identity_block(X, 3, [64,64,256])
    X = identity_block(X, 3, [64,64,256])

    X = convolutional_block(X, f = 3, filters = [128, 128, 512], s = 2)
    X = identity_block(X, 3, [128, 128, 512])
    X = identity_block(X, 3, [128, 128, 512])
    X = identity_block(X, 3, [128, 128, 512])

    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], s = 2)
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024]) 
    X = identity_block(X, 3, [256, 256, 1024]) 
    X = identity_block(X, 3, [256, 256, 1024]) 
    X = identity_block(X, 3, [256, 256, 1024]) 

    X = convolutional_block(X, f = 3, filters = [512, 512, 2048], s = 2)
    X = identity_block(X, 3, [512, 512, 2048])
    X = identity_block(X, 3, [512, 512, 2048])

    X = AveragePooling2D(pool_size=(2, 2))(X)

    X = Flatten()(X)
    X = Dense(classes, activation='softmax', kernel_initializer=glorot_uniform(seed=0))(X)

    model = Model(inputs=X_input, outputs=X)

    return model

# %%
model = ResNet50(input_shape = (64, 64, 3), classes = 6)
print(model.summary())
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  zero_padding2d_2 (ZeroPadding2  (None, 70, 70, 3)   0           ['input_3[0][0]']
#  D)
#
#  conv2d_138 (Conv2D)            (None, 32, 32, 64)   9472        ['zero_padding2d_2[0][0]']
#
#  batch_normalization_138 (Batch  (None, 32, 32, 64)  256         ['conv2d_138[0][0]']
#  Normalization)
#
#  activation_125 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_138[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 15, 15, 64)  0           ['activation_125[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 15, 15, 64)   4160        ['max_pooling2d_2[0][0]']
#
#  batch_normalization_139 (Batch  (None, 15, 15, 64)  256         ['conv2d_139[0][0]']
#  Normalization)
#
#  activation_126 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_139[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 15, 15, 64)   36928       ['activation_126[0][0]']
#
#  batch_normalization_140 (Batch  (None, 15, 15, 64)  256         ['conv2d_140[0][0]']
#  Normalization)
#
#  activation_127 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_140[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 15, 15, 256)  16640       ['activation_127[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 15, 15, 256)  16640       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_141 (Batch  (None, 15, 15, 256)  1024       ['conv2d_141[0][0]']
#  Normalization)
#
#  batch_normalization_142 (Batch  (None, 15, 15, 256)  1024       ['conv2d_142[0][0]']
#  Normalization)
#
#  add_41 (Add)                   (None, 15, 15, 256)  0           ['batch_normalization_141[0][0]',
#                                                                   'batch_normalization_142[0][0]']
#
#  activation_128 (Activation)    (None, 15, 15, 256)  0           ['add_41[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 15, 15, 64)   16448       ['activation_128[0][0]']
#
#  batch_normalization_143 (Batch  (None, 15, 15, 64)  256         ['conv2d_143[0][0]']
#  Normalization)
#
#  activation_129 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_143[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 15, 15, 64)   36928       ['activation_129[0][0]']
#
#  batch_normalization_144 (Batch  (None, 15, 15, 64)  256         ['conv2d_144[0][0]']
#  Normalization)
#
#  activation_130 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_144[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 15, 15, 256)  16640       ['activation_130[0][0]']
#
#  batch_normalization_145 (Batch  (None, 15, 15, 256)  1024       ['conv2d_145[0][0]']
#  Normalization)
#
#  add_42 (Add)                   (None, 15, 15, 256)  0           ['batch_normalization_145[0][0]',
#                                                                   'activation_128[0][0]']
#
#  activation_131 (Activation)    (None, 15, 15, 256)  0           ['add_42[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 15, 15, 64)   16448       ['activation_131[0][0]']
#
#  batch_normalization_146 (Batch  (None, 15, 15, 64)  256         ['conv2d_146[0][0]']
#  Normalization)
#
#  activation_132 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_146[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 15, 15, 64)   36928       ['activation_132[0][0]']
#
#  batch_normalization_147 (Batch  (None, 15, 15, 64)  256         ['conv2d_147[0][0]']
#  Normalization)
#
#  activation_133 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_147[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 15, 15, 256)  16640       ['activation_133[0][0]']
#
#  batch_normalization_148 (Batch  (None, 15, 15, 256)  1024       ['conv2d_148[0][0]']
#  Normalization)
#
#  add_43 (Add)                   (None, 15, 15, 256)  0           ['batch_normalization_148[0][0]',
#                                                                   'activation_131[0][0]']
#
#  activation_134 (Activation)    (None, 15, 15, 256)  0           ['add_43[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 8, 8, 128)    32896       ['activation_134[0][0]']
#
#  batch_normalization_149 (Batch  (None, 8, 8, 128)   512         ['conv2d_149[0][0]']
#  Normalization)
#
#  activation_135 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_149[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_135[0][0]']
#
#  batch_normalization_150 (Batch  (None, 8, 8, 128)   512         ['conv2d_150[0][0]']
#  Normalization)
#
#  activation_136 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_150[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 8, 8, 512)    66048       ['activation_136[0][0]']
#
#  conv2d_152 (Conv2D)            (None, 8, 8, 512)    131584      ['activation_134[0][0]']
#
#  batch_normalization_151 (Batch  (None, 8, 8, 512)   2048        ['conv2d_151[0][0]']
#  Normalization)
#
#  batch_normalization_152 (Batch  (None, 8, 8, 512)   2048        ['conv2d_152[0][0]']
#  Normalization)
#
#  add_44 (Add)                   (None, 8, 8, 512)    0           ['batch_normalization_151[0][0]',
#                                                                   'batch_normalization_152[0][0]']
#
#  activation_137 (Activation)    (None, 8, 8, 512)    0           ['add_44[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 8, 8, 128)    65664       ['activation_137[0][0]']
#
#  batch_normalization_153 (Batch  (None, 8, 8, 128)   512         ['conv2d_153[0][0]']
#  Normalization)
#
#  activation_138 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_153[0][0]']
#
#  conv2d_154 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_138[0][0]']
#
#  batch_normalization_154 (Batch  (None, 8, 8, 128)   512         ['conv2d_154[0][0]']
#  Normalization)
#
#  activation_139 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_154[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 8, 8, 512)    66048       ['activation_139[0][0]']
#
#  batch_normalization_155 (Batch  (None, 8, 8, 512)   2048        ['conv2d_155[0][0]']
#  Normalization)
#
#  add_45 (Add)                   (None, 8, 8, 512)    0           ['batch_normalization_155[0][0]',
#                                                                   'activation_137[0][0]']
#
#  activation_140 (Activation)    (None, 8, 8, 512)    0           ['add_45[0][0]']
#
#  conv2d_156 (Conv2D)            (None, 8, 8, 128)    65664       ['activation_140[0][0]']
#
#  batch_normalization_156 (Batch  (None, 8, 8, 128)   512         ['conv2d_156[0][0]']
#  Normalization)
#
#  activation_141 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_156[0][0]']
#
#  conv2d_157 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_141[0][0]']
#
#  batch_normalization_157 (Batch  (None, 8, 8, 128)   512         ['conv2d_157[0][0]']
#  Normalization)
#
#  activation_142 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_157[0][0]']
#
#  conv2d_158 (Conv2D)            (None, 8, 8, 512)    66048       ['activation_142[0][0]']
#
#  batch_normalization_158 (Batch  (None, 8, 8, 512)   2048        ['conv2d_158[0][0]']
#  Normalization)
#
#  add_46 (Add)                   (None, 8, 8, 512)    0           ['batch_normalization_158[0][0]',
#                                                                   'activation_140[0][0]']
#
#  activation_143 (Activation)    (None, 8, 8, 512)    0           ['add_46[0][0]']
#
#  conv2d_159 (Conv2D)            (None, 8, 8, 128)    65664       ['activation_143[0][0]']
#
#  batch_normalization_159 (Batch  (None, 8, 8, 128)   512         ['conv2d_159[0][0]']
#  Normalization)
#
#  activation_144 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_159[0][0]']
#
#  conv2d_160 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_144[0][0]']
#
#  batch_normalization_160 (Batch  (None, 8, 8, 128)   512         ['conv2d_160[0][0]']
#  Normalization)
#
#  activation_145 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_160[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 8, 8, 512)    66048       ['activation_145[0][0]']
#
#  batch_normalization_161 (Batch  (None, 8, 8, 512)   2048        ['conv2d_161[0][0]']
#  Normalization)
#
#  add_47 (Add)                   (None, 8, 8, 512)    0           ['batch_normalization_161[0][0]',
#                                                                   'activation_143[0][0]']
#
#  activation_146 (Activation)    (None, 8, 8, 512)    0           ['add_47[0][0]']
#
#  conv2d_162 (Conv2D)            (None, 4, 4, 256)    131328      ['activation_146[0][0]']
#
#  batch_normalization_162 (Batch  (None, 4, 4, 256)   1024        ['conv2d_162[0][0]']
#  Normalization)
#
#  activation_147 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_162[0][0]']
#
#  conv2d_163 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_147[0][0]']
#
#  batch_normalization_163 (Batch  (None, 4, 4, 256)   1024        ['conv2d_163[0][0]']
#  Normalization)
#
#  activation_148 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_163[0][0]']
#
#  conv2d_164 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_148[0][0]']
#
#  conv2d_165 (Conv2D)            (None, 4, 4, 1024)   525312      ['activation_146[0][0]']
#
#  batch_normalization_164 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_164[0][0]']
#  Normalization)
#
#  batch_normalization_165 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_165[0][0]']
#  Normalization)
#
#  add_48 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_164[0][0]',
#                                                                   'batch_normalization_165[0][0]']
#
#  activation_149 (Activation)    (None, 4, 4, 1024)   0           ['add_48[0][0]']
#
#  conv2d_166 (Conv2D)            (None, 4, 4, 256)    262400      ['activation_149[0][0]']
#
#  batch_normalization_166 (Batch  (None, 4, 4, 256)   1024        ['conv2d_166[0][0]']
#  Normalization)
#
#  activation_150 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_166[0][0]']
#
#  conv2d_167 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_150[0][0]']
#
#  batch_normalization_167 (Batch  (None, 4, 4, 256)   1024        ['conv2d_167[0][0]']
#  Normalization)
#
#  activation_151 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_167[0][0]']
#
#  conv2d_168 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_151[0][0]']
#
#  batch_normalization_168 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_168[0][0]']
#  Normalization)
#
#  add_49 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_168[0][0]',
#                                                                   'activation_149[0][0]']
#
#  activation_152 (Activation)    (None, 4, 4, 1024)   0           ['add_49[0][0]']
#
#  conv2d_169 (Conv2D)            (None, 4, 4, 256)    262400      ['activation_152[0][0]']
#
#  batch_normalization_169 (Batch  (None, 4, 4, 256)   1024        ['conv2d_169[0][0]']
#  Normalization)
#
#  activation_153 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_169[0][0]']
#
#  conv2d_170 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_153[0][0]']
#
#  batch_normalization_170 (Batch  (None, 4, 4, 256)   1024        ['conv2d_170[0][0]']
#  Normalization)
#
#  activation_154 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_170[0][0]']
#
#  conv2d_171 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_154[0][0]']
#
#  batch_normalization_171 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_171[0][0]']
#  Normalization)
#
#  add_50 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_171[0][0]',
#                                                                   'activation_152[0][0]']
#
#  activation_155 (Activation)    (None, 4, 4, 1024)   0           ['add_50[0][0]']
#
#  conv2d_172 (Conv2D)            (None, 4, 4, 256)    262400      ['activation_155[0][0]']
#
#  batch_normalization_172 (Batch  (None, 4, 4, 256)   1024        ['conv2d_172[0][0]']
#  Normalization)
#
#  activation_156 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_172[0][0]']
#
#  conv2d_173 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_156[0][0]']
#
#  batch_normalization_173 (Batch  (None, 4, 4, 256)   1024        ['conv2d_173[0][0]']
#  Normalization)
#
#  activation_157 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_173[0][0]']
#
#  conv2d_174 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_157[0][0]']
#
#  batch_normalization_174 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_174[0][0]']
#  Normalization)
#
#  add_51 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_174[0][0]',
#                                                                   'activation_155[0][0]']
#
#  activation_158 (Activation)    (None, 4, 4, 1024)   0           ['add_51[0][0]']
#
#  conv2d_175 (Conv2D)            (None, 4, 4, 256)    262400      ['activation_158[0][0]']
#
#  batch_normalization_175 (Batch  (None, 4, 4, 256)   1024        ['conv2d_175[0][0]']
#  Normalization)
#
#  activation_159 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_175[0][0]']
#
#  conv2d_176 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_159[0][0]']
#
#  batch_normalization_176 (Batch  (None, 4, 4, 256)   1024        ['conv2d_176[0][0]']
#  Normalization)
#
#  activation_160 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_176[0][0]']
#
#  conv2d_177 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_160[0][0]']
#
#  batch_normalization_177 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_177[0][0]']
#  Normalization)
#
#  add_52 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_177[0][0]',
#                                                                   'activation_158[0][0]']
#
#  activation_161 (Activation)    (None, 4, 4, 1024)   0           ['add_52[0][0]']
#
#  conv2d_178 (Conv2D)            (None, 4, 4, 256)    262400      ['activation_161[0][0]']
#
#  batch_normalization_178 (Batch  (None, 4, 4, 256)   1024        ['conv2d_178[0][0]']
#  Normalization)
#
#  activation_162 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_178[0][0]']
#
#  conv2d_179 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_162[0][0]']
#
#  batch_normalization_179 (Batch  (None, 4, 4, 256)   1024        ['conv2d_179[0][0]']
#  Normalization)
#
#  activation_163 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_179[0][0]']
#
#  conv2d_180 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_163[0][0]']
#
#  batch_normalization_180 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_180[0][0]']
#  Normalization)
#
#  add_53 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_180[0][0]',
#                                                                   'activation_161[0][0]']
#
#  activation_164 (Activation)    (None, 4, 4, 1024)   0           ['add_53[0][0]']
#
#  conv2d_181 (Conv2D)            (None, 2, 2, 512)    524800      ['activation_164[0][0]']
#
#  batch_normalization_181 (Batch  (None, 2, 2, 512)   2048        ['conv2d_181[0][0]']
#  Normalization)
#
#  activation_165 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_181[0][0]']
#
#  conv2d_182 (Conv2D)            (None, 2, 2, 512)    2359808     ['activation_165[0][0]']
#
#  batch_normalization_182 (Batch  (None, 2, 2, 512)   2048        ['conv2d_182[0][0]']
#  Normalization)
#
#  activation_166 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_182[0][0]']
#
#  conv2d_183 (Conv2D)            (None, 2, 2, 2048)   1050624     ['activation_166[0][0]']
#
#  conv2d_184 (Conv2D)            (None, 2, 2, 2048)   2099200     ['activation_164[0][0]']
#
#  batch_normalization_183 (Batch  (None, 2, 2, 2048)  8192        ['conv2d_183[0][0]']
#  Normalization)
#
#  batch_normalization_184 (Batch  (None, 2, 2, 2048)  8192        ['conv2d_184[0][0]']
#  Normalization)
#
#  add_54 (Add)                   (None, 2, 2, 2048)   0           ['batch_normalization_183[0][0]',
#                                                                   'batch_normalization_184[0][0]']
#
#  activation_167 (Activation)    (None, 2, 2, 2048)   0           ['add_54[0][0]']
#
#  conv2d_185 (Conv2D)            (None, 2, 2, 512)    1049088     ['activation_167[0][0]']
#
#  batch_normalization_185 (Batch  (None, 2, 2, 512)   2048        ['conv2d_185[0][0]']
#  Normalization)
#
#  activation_168 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_185[0][0]']
#
#  conv2d_186 (Conv2D)            (None, 2, 2, 512)    2359808     ['activation_168[0][0]']
#
#  batch_normalization_186 (Batch  (None, 2, 2, 512)   2048        ['conv2d_186[0][0]']
#  Normalization)
#
#  activation_169 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_186[0][0]']
#
#  conv2d_187 (Conv2D)            (None, 2, 2, 2048)   1050624     ['activation_169[0][0]']
#
#  batch_normalization_187 (Batch  (None, 2, 2, 2048)  8192        ['conv2d_187[0][0]']
#  Normalization)
#
#  add_55 (Add)                   (None, 2, 2, 2048)   0           ['batch_normalization_187[0][0]',
#                                                                   'activation_167[0][0]']
#
#  activation_170 (Activation)    (None, 2, 2, 2048)   0           ['add_55[0][0]']
#
#  conv2d_188 (Conv2D)            (None, 2, 2, 512)    1049088     ['activation_170[0][0]']
#
#  batch_normalization_188 (Batch  (None, 2, 2, 512)   2048        ['conv2d_188[0][0]']
#  Normalization)
#
#  activation_171 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_188[0][0]']
#
#  conv2d_189 (Conv2D)            (None, 2, 2, 512)    2359808     ['activation_171[0][0]']
#
#  batch_normalization_189 (Batch  (None, 2, 2, 512)   2048        ['conv2d_189[0][0]']
#  Normalization)
#
#  activation_172 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_189[0][0]']
#
#  conv2d_190 (Conv2D)            (None, 2, 2, 2048)   1050624     ['activation_172[0][0]']
#
#  batch_normalization_190 (Batch  (None, 2, 2, 2048)  8192        ['conv2d_190[0][0]']
#  Normalization)
#
#  add_56 (Add)                   (None, 2, 2, 2048)   0           ['batch_normalization_190[0][0]',
#                                                                   'activation_170[0][0]']
#
#  activation_173 (Activation)    (None, 2, 2, 2048)   0           ['add_56[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 1, 1, 2048)  0           ['activation_173[0][0]']
#  oling2D)
#
#  flatten_2 (Flatten)            (None, 2048)         0           ['average_pooling2d_2[0][0]']
#
#  dense_2 (Dense)                (None, 6)            12294       ['flatten_2[0][0]']
#
# ==================================================================================================
# Total params: 23,600,006
# Trainable params: 23,546,886
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# None

# %%
from outputs import ResNet50_summary

model = ResNet50(input_shape = (64, 64, 3), classes = 6)

comparator(summary(model), ResNet50_summary)
# Out:
# All tests passed!

# %%
# Compile the model before training

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_dataset()

# Normalize image vectors
X_train = X_train_orig / 255.
X_test = X_test_orig / 255.

# Convert training and test labels to one hot matrices
Y_train = convert_to_one_hot(Y_train_orig, 6).T
Y_test = convert_to_one_hot(Y_test_orig, 6).T

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 1080
# number of test examples = 120
# X_train shape: (1080, 64, 64, 3)
# Y_train shape: (1080, 6)
# X_test shape: (120, 64, 64, 3)
# Y_test shape: (120, 6)

# %%
model.fit(X_train, Y_train, epochs = 10, batch_size = 32)
# Out:
# Epoch 1/10
# 34/34 [==============================] - 46s 1s/step - loss: 1.7682 - accuracy: 0.4963
# Epoch 2/10
# 34/34 [==============================] - 42s 1s/step - loss: 0.8355 - accuracy: 0.7481
# Epoch 3/10
# 34/34 [==============================] - 41s 1s/step - loss: 0.4459 - accuracy: 0.8639
# Epoch 4/10
# 34/34 [==============================] - 42s 1s/step - loss: 0.2360 - accuracy: 0.9287
# Epoch 5/10
# 34/34 [==============================] - 40s 1s/step - loss: 0.2771 - accuracy: 0.9185
# Epoch 6/10
# 34/34 [==============================] - 39s 1s/step - loss: 0.2612 - accuracy: 0.9278
# Epoch 7/10
# 34/34 [==============================] - 40s 1s/step - loss: 0.2693 - accuracy: 0.9231
# Epoch 8/10
# 34/34 [==============================] - 40s 1s/step - loss: 0.2059 - accuracy: 0.9509
# Epoch 9/10
# 34/34 [==============================] - 40s 1s/step - loss: 0.1265 - accuracy: 0.9574
# Epoch 10/10
# 34/34 [==============================] - 40s 1s/step - loss: 0.0813 - accuracy: 0.9759

# %%
preds = model.evaluate(X_test, Y_test)
print('Loss =' + str(preds[0]))
print('Test Accuracy =' + str(preds[1]))
# Out:
# 4/4 [==============================] - 1s 229ms/step - loss: 0.2518 - accuracy: 0.9417
# Loss =0.2518129050731659
# Test Accuracy =0.9416666626930237
